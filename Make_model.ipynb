# %%
import pandas as pd
import cv2
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2

# %%
dataset_path = '/content/drive/MyDrive//fer2013.csv'
image_size=(48,48)

# %%
def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

# %%
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x

# %%
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)

# %%
batch_size = 32
num_epochs = 150
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/content/drive/MyDrive/models/'
l2_regularization=0.01

# %%
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l2(l2_regularization)

# %%
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# %%
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 46, 46, 8)    72          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 46, 46, 8)   32          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 46, 46, 8)    0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 44, 44, 8)    576         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 44, 44, 8)   32          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 44, 44, 8)    0           ['batch_normalization_1[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 44, 44, 16)  200         ['activation_1[0][0]']
#  v2D)
#
#  batch_normalization_3 (BatchNo  (None, 44, 44, 16)  64          ['separable_conv2d[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 44, 44, 16)   0           ['batch_normalization_3[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 44, 44, 16)  400         ['activation_2[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 44, 44, 16)  64          ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 22, 22, 16)   128         ['activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 22, 22, 16)   0           ['batch_normalization_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 22, 22, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 22, 22, 16)   0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 22, 22, 32)  656         ['add[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 22, 22, 32)  128         ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 22, 22, 32)   0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 22, 22, 32)  1312        ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 22, 22, 32)  128         ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 11, 11, 32)   512         ['add[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 32)  0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 11, 11, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 11, 11, 32)   0           ['max_pooling2d_1[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 11, 11, 64)  2336        ['add_1[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 11, 11, 64)  256         ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 11, 11, 64)   0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 11, 11, 64)  4672        ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 11, 11, 64)  256         ['separable_conv2d_5[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)              (None, 6, 6, 64)     2048        ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 64)    0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 6, 6, 64)    256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 6, 6, 64)     0           ['max_pooling2d_2[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 6, 6, 128)   8768        ['add_2[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 6, 6, 128)   512         ['separable_conv2d_6[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 6, 6, 128)    0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 6, 6, 128)   17536       ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 6, 6, 128)   512         ['separable_conv2d_7[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)              (None, 3, 3, 128)    8192        ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 3, 3, 128)   0           ['batch_normalization_13[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 3, 3, 128)   512         ['conv2d_5[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 3, 3, 128)    0           ['max_pooling2d_3[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 3, 3, 7)      8071        ['add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 7)           0           ['conv2d_6[0][0]']
#  alAveragePooling2D)
#
#  predictions (Activation)       (None, 7)            0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# <ipython-input-12-ac72e9e38f20>:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
# Epoch 1/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.7746 - accuracy: 0.3307
# Epoch 1: val_loss improved from inf to 1.66165, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.01-0.38.hdf5
# 897/897 [==============================] - 44s 30ms/step - loss: 1.7741 - accuracy: 0.3310 - val_loss: 1.6616 - val_accuracy: 0.3844 - lr: 0.0010
# Epoch 2/150
# 898/897 [==============================] - ETA: 0s - loss: 1.5168 - accuracy: 0.4312
# Epoch 2: val_loss improved from 1.66165 to 1.46208, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.02-0.45.hdf5
# 897/897 [==============================] - 25s 28ms/step - loss: 1.5168 - accuracy: 0.4312 - val_loss: 1.4621 - val_accuracy: 0.4544 - lr: 0.0010
# Epoch 3/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.3879 - accuracy: 0.4798
# Epoch 3: val_loss did not improve from 1.46208
# 897/897 [==============================] - 22s 25ms/step - loss: 1.3876 - accuracy: 0.4800 - val_loss: 1.6366 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 4/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.3130 - accuracy: 0.5087
# Epoch 4: val_loss improved from 1.46208 to 1.32292, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.04-0.50.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 1.3127 - accuracy: 0.5088 - val_loss: 1.3229 - val_accuracy: 0.5035 - lr: 0.0010
# Epoch 5/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2676 - accuracy: 0.5251
# Epoch 5: val_loss improved from 1.32292 to 1.31218, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.05-0.51.hdf5
# 897/897 [==============================] - 22s 25ms/step - loss: 1.2676 - accuracy: 0.5251 - val_loss: 1.3122 - val_accuracy: 0.5149 - lr: 0.0010
# Epoch 6/150
# 898/897 [==============================] - ETA: 0s - loss: 1.2341 - accuracy: 0.5344
# Epoch 6: val_loss improved from 1.31218 to 1.24416, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.06-0.53.hdf5
# 897/897 [==============================] - 24s 26ms/step - loss: 1.2341 - accuracy: 0.5344 - val_loss: 1.2442 - val_accuracy: 0.5309 - lr: 0.0010
# Epoch 7/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.2017 - accuracy: 0.5504
# Epoch 7: val_loss improved from 1.24416 to 1.20632, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.07-0.55.hdf5
# 897/897 [==============================] - 23s 26ms/step - loss: 1.2015 - accuracy: 0.5506 - val_loss: 1.2063 - val_accuracy: 0.5508 - lr: 0.0010
# Epoch 8/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1827 - accuracy: 0.5577
# Epoch 8: val_loss did not improve from 1.20632
# 897/897 [==============================] - 22s 25ms/step - loss: 1.1827 - accuracy: 0.5577 - val_loss: 1.2120 - val_accuracy: 0.5396 - lr: 0.0010
# Epoch 9/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.1682 - accuracy: 0.5616
# Epoch 9: val_loss improved from 1.20632 to 1.16840, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.09-0.56.hdf5
# 897/897 [==============================] - 24s 26ms/step - loss: 1.1682 - accuracy: 0.5615 - val_loss: 1.1684 - val_accuracy: 0.5585 - lr: 0.0010
# Epoch 10/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1492 - accuracy: 0.5698
# Epoch 10: val_loss did not improve from 1.16840
# 897/897 [==============================] - 24s 27ms/step - loss: 1.1492 - accuracy: 0.5698 - val_loss: 1.2004 - val_accuracy: 0.5559 - lr: 0.0010
# Epoch 11/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.1376 - accuracy: 0.5718
# Epoch 11: val_loss did not improve from 1.16840
# 897/897 [==============================] - 23s 26ms/step - loss: 1.1380 - accuracy: 0.5718 - val_loss: 1.1695 - val_accuracy: 0.5606 - lr: 0.0010
# Epoch 12/150
# 898/897 [==============================] - ETA: 0s - loss: 1.1241 - accuracy: 0.5792
# Epoch 12: val_loss did not improve from 1.16840
# 897/897 [==============================] - 24s 26ms/step - loss: 1.1241 - accuracy: 0.5792 - val_loss: 1.2366 - val_accuracy: 0.5454 - lr: 0.0010
# Epoch 13/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.1066 - accuracy: 0.5867
# Epoch 13: val_loss improved from 1.16840 to 1.16668, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.13-0.57.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 1.1066 - accuracy: 0.5866 - val_loss: 1.1667 - val_accuracy: 0.5665 - lr: 0.0010
# Epoch 14/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.1019 - accuracy: 0.5897
# Epoch 14: val_loss did not improve from 1.16668
# 897/897 [==============================] - 23s 25ms/step - loss: 1.1016 - accuracy: 0.5898 - val_loss: 1.1771 - val_accuracy: 0.5563 - lr: 0.0010
# Epoch 15/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.0888 - accuracy: 0.5953
# Epoch 15: val_loss improved from 1.16668 to 1.10746, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.15-0.58.hdf5
# 897/897 [==============================] - 22s 25ms/step - loss: 1.0888 - accuracy: 0.5952 - val_loss: 1.1075 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 16/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0803 - accuracy: 0.5966
# Epoch 16: val_loss improved from 1.10746 to 1.10668, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.16-0.58.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0804 - accuracy: 0.5965 - val_loss: 1.1067 - val_accuracy: 0.5805 - lr: 0.0010
# Epoch 17/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0741 - accuracy: 0.5994
# Epoch 17: val_loss did not improve from 1.10668
# 897/897 [==============================] - 22s 25ms/step - loss: 1.0741 - accuracy: 0.5994 - val_loss: 1.1784 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 18/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0670 - accuracy: 0.6004
# Epoch 18: val_loss did not improve from 1.10668
# 897/897 [==============================] - 22s 25ms/step - loss: 1.0668 - accuracy: 0.6005 - val_loss: 1.1203 - val_accuracy: 0.5790 - lr: 0.0010
# Epoch 19/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0591 - accuracy: 0.6041
# Epoch 19: val_loss did not improve from 1.10668
# 897/897 [==============================] - 23s 26ms/step - loss: 1.0591 - accuracy: 0.6041 - val_loss: 1.2852 - val_accuracy: 0.5159 - lr: 0.0010
# Epoch 20/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0554 - accuracy: 0.6058
# Epoch 20: val_loss did not improve from 1.10668
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0550 - accuracy: 0.6059 - val_loss: 1.1203 - val_accuracy: 0.5702 - lr: 0.0010
# Epoch 21/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0407 - accuracy: 0.6096
# Epoch 21: val_loss did not improve from 1.10668
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0407 - accuracy: 0.6096 - val_loss: 1.1251 - val_accuracy: 0.5741 - lr: 0.0010
# Epoch 22/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.0430 - accuracy: 0.6117
# Epoch 22: val_loss improved from 1.10668 to 1.07439, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.22-0.60.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0429 - accuracy: 0.6118 - val_loss: 1.0744 - val_accuracy: 0.5974 - lr: 0.0010
# Epoch 23/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0334 - accuracy: 0.6132
# Epoch 23: val_loss did not improve from 1.07439
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0336 - accuracy: 0.6130 - val_loss: 1.0772 - val_accuracy: 0.5970 - lr: 0.0010
# Epoch 24/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0303 - accuracy: 0.6133
# Epoch 24: val_loss improved from 1.07439 to 1.07377, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.24-0.60.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0303 - accuracy: 0.6133 - val_loss: 1.0738 - val_accuracy: 0.6021 - lr: 0.0010
# Epoch 25/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.0290 - accuracy: 0.6148
# Epoch 25: val_loss did not improve from 1.07377
# 897/897 [==============================] - 23s 26ms/step - loss: 1.0290 - accuracy: 0.6148 - val_loss: 1.1002 - val_accuracy: 0.5848 - lr: 0.0010
# Epoch 26/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.0179 - accuracy: 0.6210
# Epoch 26: val_loss did not improve from 1.07377
# 897/897 [==============================] - 24s 26ms/step - loss: 1.0185 - accuracy: 0.6207 - val_loss: 1.1130 - val_accuracy: 0.5832 - lr: 0.0010
# Epoch 27/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0116 - accuracy: 0.6235
# Epoch 27: val_loss improved from 1.07377 to 1.06785, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.27-0.60.hdf5
# 897/897 [==============================] - 22s 25ms/step - loss: 1.0115 - accuracy: 0.6237 - val_loss: 1.0678 - val_accuracy: 0.5995 - lr: 0.0010
# Epoch 28/150
# 896/897 [============================>.] - ETA: 0s - loss: 1.0104 - accuracy: 0.6209
# Epoch 28: val_loss did not improve from 1.06785
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0103 - accuracy: 0.6209 - val_loss: 1.0742 - val_accuracy: 0.5978 - lr: 0.0010
# Epoch 29/150
# 897/897 [============================>.] - ETA: 0s - loss: 1.0036 - accuracy: 0.6261
# Epoch 29: val_loss did not improve from 1.06785
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0037 - accuracy: 0.6260 - val_loss: 1.0765 - val_accuracy: 0.5974 - lr: 0.0010
# Epoch 30/150
# 898/897 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.6241
# Epoch 30: val_loss did not improve from 1.06785
# 897/897 [==============================] - 24s 27ms/step - loss: 1.0029 - accuracy: 0.6241 - val_loss: 1.0681 - val_accuracy: 0.6076 - lr: 0.0010
# Epoch 31/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9960 - accuracy: 0.6299
# Epoch 31: val_loss did not improve from 1.06785
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9960 - accuracy: 0.6299 - val_loss: 1.0689 - val_accuracy: 0.6070 - lr: 0.0010
# Epoch 32/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9956 - accuracy: 0.6304
# Epoch 32: val_loss did not improve from 1.06785
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9960 - accuracy: 0.6304 - val_loss: 1.0863 - val_accuracy: 0.5982 - lr: 0.0010
# Epoch 33/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9922 - accuracy: 0.6313
# Epoch 33: val_loss improved from 1.06785 to 1.05726, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.33-0.60.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9923 - accuracy: 0.6313 - val_loss: 1.0573 - val_accuracy: 0.6042 - lr: 0.0010
# Epoch 34/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9890 - accuracy: 0.6324
# Epoch 34: val_loss did not improve from 1.05726
# 897/897 [==============================] - 23s 26ms/step - loss: 0.9889 - accuracy: 0.6325 - val_loss: 1.1066 - val_accuracy: 0.5913 - lr: 0.0010
# Epoch 35/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9863 - accuracy: 0.6336
# Epoch 35: val_loss did not improve from 1.05726
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9859 - accuracy: 0.6339 - val_loss: 1.1119 - val_accuracy: 0.5840 - lr: 0.0010
# Epoch 36/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9822 - accuracy: 0.6374
# Epoch 36: val_loss did not improve from 1.05726
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9819 - accuracy: 0.6375 - val_loss: 1.0785 - val_accuracy: 0.5992 - lr: 0.0010
# Epoch 37/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9742 - accuracy: 0.6367
# Epoch 37: val_loss did not improve from 1.05726
# 897/897 [==============================] - 25s 27ms/step - loss: 0.9742 - accuracy: 0.6367 - val_loss: 1.1112 - val_accuracy: 0.5896 - lr: 0.0010
# Epoch 38/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9736 - accuracy: 0.6372
# Epoch 38: val_loss improved from 1.05726 to 1.05150, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.38-0.61.hdf5
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9735 - accuracy: 0.6372 - val_loss: 1.0515 - val_accuracy: 0.6127 - lr: 0.0010
# Epoch 39/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9753 - accuracy: 0.6389
# Epoch 39: val_loss did not improve from 1.05150
# 897/897 [==============================] - 25s 27ms/step - loss: 0.9750 - accuracy: 0.6389 - val_loss: 1.1644 - val_accuracy: 0.5789 - lr: 0.0010
# Epoch 40/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9763 - accuracy: 0.6388
# Epoch 40: val_loss did not improve from 1.05150
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9763 - accuracy: 0.6388 - val_loss: 1.1013 - val_accuracy: 0.5950 - lr: 0.0010
# Epoch 41/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.6403
# Epoch 41: val_loss did not improve from 1.05150
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9711 - accuracy: 0.6403 - val_loss: 1.0959 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 42/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9602 - accuracy: 0.6455
# Epoch 42: val_loss did not improve from 1.05150
# 897/897 [==============================] - 23s 25ms/step - loss: 0.9599 - accuracy: 0.6456 - val_loss: 1.0753 - val_accuracy: 0.6031 - lr: 0.0010
# Epoch 43/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9585 - accuracy: 0.6435
# Epoch 43: val_loss did not improve from 1.05150
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9587 - accuracy: 0.6435 - val_loss: 1.0520 - val_accuracy: 0.6091 - lr: 0.0010
# Epoch 44/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9600 - accuracy: 0.6433
# Epoch 44: val_loss did not improve from 1.05150
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9600 - accuracy: 0.6432 - val_loss: 1.0855 - val_accuracy: 0.6006 - lr: 0.0010
# Epoch 45/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6426
# Epoch 45: val_loss improved from 1.05150 to 1.04540, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.45-0.61.hdf5
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9597 - accuracy: 0.6426 - val_loss: 1.0454 - val_accuracy: 0.6092 - lr: 0.0010
# Epoch 46/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9483 - accuracy: 0.6455
# Epoch 46: val_loss did not improve from 1.04540
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9481 - accuracy: 0.6455 - val_loss: 1.0999 - val_accuracy: 0.6011 - lr: 0.0010
# Epoch 47/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9547 - accuracy: 0.6469
# Epoch 47: val_loss did not improve from 1.04540
# 897/897 [==============================] - 23s 25ms/step - loss: 0.9546 - accuracy: 0.6470 - val_loss: 1.0507 - val_accuracy: 0.6089 - lr: 0.0010
# Epoch 48/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9441 - accuracy: 0.6479
# Epoch 48: val_loss improved from 1.04540 to 1.02425, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.48-0.62.hdf5
# 897/897 [==============================] - 25s 27ms/step - loss: 0.9441 - accuracy: 0.6479 - val_loss: 1.0242 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 49/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9464 - accuracy: 0.6516
# Epoch 49: val_loss did not improve from 1.02425
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9463 - accuracy: 0.6515 - val_loss: 1.0591 - val_accuracy: 0.6108 - lr: 0.0010
# Epoch 50/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9407 - accuracy: 0.6522
# Epoch 50: val_loss improved from 1.02425 to 1.02276, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.50-0.62.hdf5
# 897/897 [==============================] - 23s 25ms/step - loss: 0.9406 - accuracy: 0.6521 - val_loss: 1.0228 - val_accuracy: 0.6216 - lr: 0.0010
# Epoch 51/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9368 - accuracy: 0.6507
# Epoch 51: val_loss did not improve from 1.02276
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9368 - accuracy: 0.6507 - val_loss: 1.0475 - val_accuracy: 0.6084 - lr: 0.0010
# Epoch 52/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9351 - accuracy: 0.6529
# Epoch 52: val_loss did not improve from 1.02276
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9351 - accuracy: 0.6528 - val_loss: 1.0391 - val_accuracy: 0.6195 - lr: 0.0010
# Epoch 53/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9366 - accuracy: 0.6544
# Epoch 53: val_loss did not improve from 1.02276
# 897/897 [==============================] - 23s 26ms/step - loss: 0.9366 - accuracy: 0.6544 - val_loss: 1.0364 - val_accuracy: 0.6211 - lr: 0.0010
# Epoch 54/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9387 - accuracy: 0.6510
# Epoch 54: val_loss did not improve from 1.02276
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9382 - accuracy: 0.6512 - val_loss: 1.0232 - val_accuracy: 0.6282 - lr: 0.0010
# Epoch 55/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9318 - accuracy: 0.6525
# Epoch 55: val_loss did not improve from 1.02276
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9318 - accuracy: 0.6525 - val_loss: 1.0338 - val_accuracy: 0.6191 - lr: 0.0010
# Epoch 56/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9295 - accuracy: 0.6561
# Epoch 56: val_loss did not improve from 1.02276
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9295 - accuracy: 0.6561 - val_loss: 1.0574 - val_accuracy: 0.6183 - lr: 0.0010
# Epoch 57/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9245 - accuracy: 0.6580
# Epoch 57: val_loss did not improve from 1.02276
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9248 - accuracy: 0.6580 - val_loss: 1.0689 - val_accuracy: 0.6101 - lr: 0.0010
# Epoch 58/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9285 - accuracy: 0.6527
# Epoch 58: val_loss did not improve from 1.02276
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9284 - accuracy: 0.6528 - val_loss: 1.0410 - val_accuracy: 0.6121 - lr: 0.0010
# Epoch 59/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.6564
# Epoch 59: val_loss did not improve from 1.02276
# 897/897 [==============================] - 25s 27ms/step - loss: 0.9244 - accuracy: 0.6564 - val_loss: 1.0592 - val_accuracy: 0.6102 - lr: 0.0010
# Epoch 60/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9218 - accuracy: 0.6575
# Epoch 60: val_loss improved from 1.02276 to 1.01985, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.60-0.62.hdf5
# 897/897 [==============================] - 23s 25ms/step - loss: 0.9218 - accuracy: 0.6575 - val_loss: 1.0199 - val_accuracy: 0.6245 - lr: 0.0010
# Epoch 61/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9192 - accuracy: 0.6624
# Epoch 61: val_loss did not improve from 1.01985
# 897/897 [==============================] - 25s 28ms/step - loss: 0.9191 - accuracy: 0.6624 - val_loss: 1.0668 - val_accuracy: 0.6064 - lr: 0.0010
# Epoch 62/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9173 - accuracy: 0.6592
# Epoch 62: val_loss improved from 1.01985 to 1.01926, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.62-0.63.hdf5
# 897/897 [==============================] - 23s 25ms/step - loss: 0.9169 - accuracy: 0.6594 - val_loss: 1.0193 - val_accuracy: 0.6336 - lr: 0.0010
# Epoch 63/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9151 - accuracy: 0.6609
# Epoch 63: val_loss did not improve from 1.01926
# 897/897 [==============================] - 24s 27ms/step - loss: 0.9149 - accuracy: 0.6610 - val_loss: 1.0607 - val_accuracy: 0.6131 - lr: 0.0010
# Epoch 64/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9142 - accuracy: 0.6622
# Epoch 64: val_loss did not improve from 1.01926
# 897/897 [==============================] - 23s 26ms/step - loss: 0.9141 - accuracy: 0.6622 - val_loss: 1.0637 - val_accuracy: 0.6123 - lr: 0.0010
# Epoch 65/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9120 - accuracy: 0.6618
# Epoch 65: val_loss did not improve from 1.01926
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9117 - accuracy: 0.6619 - val_loss: 1.0713 - val_accuracy: 0.6163 - lr: 0.0010
# Epoch 66/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.6574
# Epoch 66: val_loss did not improve from 1.01926
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9217 - accuracy: 0.6574 - val_loss: 1.0361 - val_accuracy: 0.6201 - lr: 0.0010
# Epoch 67/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9136 - accuracy: 0.6628
# Epoch 67: val_loss did not improve from 1.01926
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9134 - accuracy: 0.6629 - val_loss: 1.0416 - val_accuracy: 0.6151 - lr: 0.0010
# Epoch 68/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9038 - accuracy: 0.6672
# Epoch 68: val_loss did not improve from 1.01926
# 897/897 [==============================] - 24s 26ms/step - loss: 0.9036 - accuracy: 0.6672 - val_loss: 1.0544 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 69/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9122 - accuracy: 0.6592
# Epoch 69: val_loss did not improve from 1.01926
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9121 - accuracy: 0.6593 - val_loss: 1.1345 - val_accuracy: 0.5900 - lr: 0.0010
# Epoch 70/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.9072 - accuracy: 0.6635
# Epoch 70: val_loss did not improve from 1.01926
# 897/897 [==============================] - 23s 26ms/step - loss: 0.9069 - accuracy: 0.6636 - val_loss: 1.0349 - val_accuracy: 0.6202 - lr: 0.0010
# Epoch 71/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9048 - accuracy: 0.6680
# Epoch 71: val_loss did not improve from 1.01926
# 897/897 [==============================] - 23s 26ms/step - loss: 0.9048 - accuracy: 0.6680 - val_loss: 1.0197 - val_accuracy: 0.6340 - lr: 0.0010
# Epoch 72/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.9025 - accuracy: 0.6650
# Epoch 72: val_loss did not improve from 1.01926
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9023 - accuracy: 0.6651 - val_loss: 1.0375 - val_accuracy: 0.6186 - lr: 0.0010
# Epoch 73/150
# 898/897 [==============================] - ETA: 0s - loss: 0.9007 - accuracy: 0.6650
# Epoch 73: val_loss did not improve from 1.01926
# 897/897 [==============================] - 22s 25ms/step - loss: 0.9007 - accuracy: 0.6650 - val_loss: 1.0482 - val_accuracy: 0.6188 - lr: 0.0010
# Epoch 74/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8998 - accuracy: 0.6672
# Epoch 74: val_loss did not improve from 1.01926
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8998 - accuracy: 0.6672 - val_loss: 1.0489 - val_accuracy: 0.6215 - lr: 0.0010
# Epoch 75/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8550 - accuracy: 0.6881
# Epoch 75: val_loss improved from 1.01926 to 0.99179, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.75-0.63.hdf5
# 897/897 [==============================] - 22s 25ms/step - loss: 0.8552 - accuracy: 0.6881 - val_loss: 0.9918 - val_accuracy: 0.6340 - lr: 1.0000e-04
# Epoch 76/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8409 - accuracy: 0.6891
# Epoch 76: val_loss improved from 0.99179 to 0.98532, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.76-0.64.hdf5
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8409 - accuracy: 0.6892 - val_loss: 0.9853 - val_accuracy: 0.6386 - lr: 1.0000e-04
# Epoch 77/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8313 - accuracy: 0.6963
# Epoch 77: val_loss improved from 0.98532 to 0.98372, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.77-0.64.hdf5
# 897/897 [==============================] - 24s 26ms/step - loss: 0.8313 - accuracy: 0.6962 - val_loss: 0.9837 - val_accuracy: 0.6406 - lr: 1.0000e-04
# Epoch 78/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8308 - accuracy: 0.6918
# Epoch 78: val_loss did not improve from 0.98372
# 897/897 [==============================] - 24s 27ms/step - loss: 0.8308 - accuracy: 0.6919 - val_loss: 0.9842 - val_accuracy: 0.6403 - lr: 1.0000e-04
# Epoch 79/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8262 - accuracy: 0.6924
# Epoch 79: val_loss did not improve from 0.98372
# 897/897 [==============================] - 23s 25ms/step - loss: 0.8263 - accuracy: 0.6923 - val_loss: 0.9840 - val_accuracy: 0.6434 - lr: 1.0000e-04
# Epoch 80/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8265 - accuracy: 0.6971
# Epoch 80: val_loss did not improve from 0.98372
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8263 - accuracy: 0.6972 - val_loss: 0.9889 - val_accuracy: 0.6408 - lr: 1.0000e-04
# Epoch 81/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8234 - accuracy: 0.6972
# Epoch 81: val_loss improved from 0.98372 to 0.98082, saving model to /content/drive/MyDrive/models/_mini_XCEPTION.81-0.64.hdf5
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8232 - accuracy: 0.6973 - val_loss: 0.9808 - val_accuracy: 0.6422 - lr: 1.0000e-04
# Epoch 82/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8224 - accuracy: 0.6958
# Epoch 82: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.8224 - accuracy: 0.6958 - val_loss: 0.9869 - val_accuracy: 0.6410 - lr: 1.0000e-04
# Epoch 83/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8192 - accuracy: 0.6976
# Epoch 83: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8190 - accuracy: 0.6977 - val_loss: 0.9841 - val_accuracy: 0.6422 - lr: 1.0000e-04
# Epoch 84/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.7017
# Epoch 84: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8120 - accuracy: 0.7017 - val_loss: 0.9837 - val_accuracy: 0.6424 - lr: 1.0000e-04
# Epoch 85/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8137 - accuracy: 0.6990
# Epoch 85: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.8135 - accuracy: 0.6992 - val_loss: 0.9909 - val_accuracy: 0.6446 - lr: 1.0000e-04
# Epoch 86/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.7002
# Epoch 86: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 26ms/step - loss: 0.8120 - accuracy: 0.7002 - val_loss: 0.9951 - val_accuracy: 0.6403 - lr: 1.0000e-04
# Epoch 87/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8181 - accuracy: 0.6966
# Epoch 87: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8184 - accuracy: 0.6965 - val_loss: 0.9931 - val_accuracy: 0.6428 - lr: 1.0000e-04
# Epoch 88/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8127 - accuracy: 0.6994
# Epoch 88: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 25ms/step - loss: 0.8125 - accuracy: 0.6995 - val_loss: 0.9938 - val_accuracy: 0.6420 - lr: 1.0000e-04
# Epoch 89/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8096 - accuracy: 0.7004
# Epoch 89: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8096 - accuracy: 0.7004 - val_loss: 0.9976 - val_accuracy: 0.6392 - lr: 1.0000e-04
# Epoch 90/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8073 - accuracy: 0.7027
# Epoch 90: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 28ms/step - loss: 0.8073 - accuracy: 0.7027 - val_loss: 0.9927 - val_accuracy: 0.6406 - lr: 1.0000e-04
# Epoch 91/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8063 - accuracy: 0.7034
# Epoch 91: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.8064 - accuracy: 0.7033 - val_loss: 0.9841 - val_accuracy: 0.6411 - lr: 1.0000e-04
# Epoch 92/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.8040 - accuracy: 0.7051
# Epoch 92: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.8043 - accuracy: 0.7048 - val_loss: 0.9856 - val_accuracy: 0.6414 - lr: 1.0000e-04
# Epoch 93/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8067 - accuracy: 0.7024
# Epoch 93: val_loss did not improve from 0.98082
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8067 - accuracy: 0.7024 - val_loss: 0.9837 - val_accuracy: 0.6417 - lr: 1.0000e-04
# Epoch 94/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7975 - accuracy: 0.7071
# Epoch 94: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 26ms/step - loss: 0.7975 - accuracy: 0.7070 - val_loss: 0.9835 - val_accuracy: 0.6431 - lr: 1.0000e-05
# Epoch 95/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7991 - accuracy: 0.7073
# Epoch 95: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7987 - accuracy: 0.7075 - val_loss: 0.9846 - val_accuracy: 0.6434 - lr: 1.0000e-05
# Epoch 96/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7979 - accuracy: 0.7051
# Epoch 96: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7980 - accuracy: 0.7051 - val_loss: 0.9850 - val_accuracy: 0.6436 - lr: 1.0000e-05
# Epoch 97/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7983 - accuracy: 0.7049
# Epoch 97: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7979 - accuracy: 0.7050 - val_loss: 0.9841 - val_accuracy: 0.6418 - lr: 1.0000e-05
# Epoch 98/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7967 - accuracy: 0.7071
# Epoch 98: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 25ms/step - loss: 0.7968 - accuracy: 0.7070 - val_loss: 0.9841 - val_accuracy: 0.6424 - lr: 1.0000e-05
# Epoch 99/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7987 - accuracy: 0.7063
# Epoch 99: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 26ms/step - loss: 0.7986 - accuracy: 0.7065 - val_loss: 0.9838 - val_accuracy: 0.6436 - lr: 1.0000e-05
# Epoch 100/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7946 - accuracy: 0.7040
# Epoch 100: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 25ms/step - loss: 0.7948 - accuracy: 0.7040 - val_loss: 0.9836 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 101/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7951 - accuracy: 0.7058
# Epoch 101: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7951 - accuracy: 0.7058 - val_loss: 0.9842 - val_accuracy: 0.6434 - lr: 1.0000e-05
# Epoch 102/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7960 - accuracy: 0.7090
# Epoch 102: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7960 - accuracy: 0.7090 - val_loss: 0.9844 - val_accuracy: 0.6436 - lr: 1.0000e-05
# Epoch 103/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7991 - accuracy: 0.7046
# Epoch 103: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7999 - accuracy: 0.7043 - val_loss: 0.9868 - val_accuracy: 0.6410 - lr: 1.0000e-05
# Epoch 104/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7975 - accuracy: 0.7043
# Epoch 104: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7972 - accuracy: 0.7044 - val_loss: 0.9861 - val_accuracy: 0.6425 - lr: 1.0000e-05
# Epoch 105/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7965 - accuracy: 0.7047
# Epoch 105: val_loss did not improve from 0.98082
#
# Epoch 105: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7965 - accuracy: 0.7047 - val_loss: 0.9869 - val_accuracy: 0.6436 - lr: 1.0000e-05
# Epoch 106/150
# 898/897 [==============================] - ETA: 0s - loss: 0.8006 - accuracy: 0.7055
# Epoch 106: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8006 - accuracy: 0.7055 - val_loss: 0.9858 - val_accuracy: 0.6439 - lr: 1.0000e-06
# Epoch 107/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7936 - accuracy: 0.7073
# Epoch 107: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7934 - accuracy: 0.7073 - val_loss: 0.9858 - val_accuracy: 0.6432 - lr: 1.0000e-06
# Epoch 108/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7992 - accuracy: 0.7026
# Epoch 108: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7990 - accuracy: 0.7027 - val_loss: 0.9855 - val_accuracy: 0.6431 - lr: 1.0000e-06
# Epoch 109/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7976 - accuracy: 0.7041
# Epoch 109: val_loss did not improve from 0.98082
# 897/897 [==============================] - 22s 25ms/step - loss: 0.7974 - accuracy: 0.7042 - val_loss: 0.9854 - val_accuracy: 0.6436 - lr: 1.0000e-06
# Epoch 110/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7950 - accuracy: 0.7084
# Epoch 110: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7950 - accuracy: 0.7084 - val_loss: 0.9854 - val_accuracy: 0.6431 - lr: 1.0000e-06
# Epoch 111/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7993 - accuracy: 0.7031
# Epoch 111: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7993 - accuracy: 0.7031 - val_loss: 0.9856 - val_accuracy: 0.6432 - lr: 1.0000e-06
# Epoch 112/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7951 - accuracy: 0.7069
# Epoch 112: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7949 - accuracy: 0.7070 - val_loss: 0.9851 - val_accuracy: 0.6429 - lr: 1.0000e-06
# Epoch 113/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7946 - accuracy: 0.7056
# Epoch 113: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7943 - accuracy: 0.7058 - val_loss: 0.9868 - val_accuracy: 0.6428 - lr: 1.0000e-06
# Epoch 114/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7972 - accuracy: 0.7066
# Epoch 114: val_loss did not improve from 0.98082
# 897/897 [==============================] - 22s 25ms/step - loss: 0.7972 - accuracy: 0.7066 - val_loss: 0.9843 - val_accuracy: 0.6436 - lr: 1.0000e-06
# Epoch 115/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7945 - accuracy: 0.7029
# Epoch 115: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7947 - accuracy: 0.7029 - val_loss: 0.9855 - val_accuracy: 0.6431 - lr: 1.0000e-06
# Epoch 116/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7973 - accuracy: 0.7053
# Epoch 116: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 27ms/step - loss: 0.7976 - accuracy: 0.7051 - val_loss: 0.9861 - val_accuracy: 0.6421 - lr: 1.0000e-06
# Epoch 117/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7974 - accuracy: 0.7073
# Epoch 117: val_loss did not improve from 0.98082
#
# Epoch 117: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7975 - accuracy: 0.7072 - val_loss: 0.9854 - val_accuracy: 0.6441 - lr: 1.0000e-06
# Epoch 118/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7951 - accuracy: 0.7071
# Epoch 118: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 25ms/step - loss: 0.7948 - accuracy: 0.7072 - val_loss: 0.9858 - val_accuracy: 0.6427 - lr: 1.0000e-07
# Epoch 119/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7912 - accuracy: 0.7080
# Epoch 119: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 26ms/step - loss: 0.7912 - accuracy: 0.7080 - val_loss: 0.9861 - val_accuracy: 0.6441 - lr: 1.0000e-07
# Epoch 120/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7927 - accuracy: 0.7088
# Epoch 120: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7927 - accuracy: 0.7088 - val_loss: 0.9858 - val_accuracy: 0.6421 - lr: 1.0000e-07
# Epoch 121/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7974 - accuracy: 0.7045
# Epoch 121: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 28ms/step - loss: 0.7973 - accuracy: 0.7046 - val_loss: 0.9848 - val_accuracy: 0.6441 - lr: 1.0000e-07
# Epoch 122/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7890 - accuracy: 0.7088
# Epoch 122: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7890 - accuracy: 0.7088 - val_loss: 0.9861 - val_accuracy: 0.6439 - lr: 1.0000e-07
# Epoch 123/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7940 - accuracy: 0.7060
# Epoch 123: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 27ms/step - loss: 0.7940 - accuracy: 0.7060 - val_loss: 0.9865 - val_accuracy: 0.6428 - lr: 1.0000e-07
# Epoch 124/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.8055 - accuracy: 0.7031
# Epoch 124: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.8054 - accuracy: 0.7030 - val_loss: 0.9858 - val_accuracy: 0.6427 - lr: 1.0000e-07
# Epoch 125/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7923 - accuracy: 0.7080
# Epoch 125: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7923 - accuracy: 0.7080 - val_loss: 0.9857 - val_accuracy: 0.6427 - lr: 1.0000e-07
# Epoch 126/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7961 - accuracy: 0.7051
# Epoch 126: val_loss did not improve from 0.98082
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7961 - accuracy: 0.7051 - val_loss: 0.9875 - val_accuracy: 0.6425 - lr: 1.0000e-07
# Epoch 127/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7920 - accuracy: 0.7072
# Epoch 127: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 28ms/step - loss: 0.7917 - accuracy: 0.7072 - val_loss: 0.9874 - val_accuracy: 0.6429 - lr: 1.0000e-07
# Epoch 128/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7910 - accuracy: 0.7096
# Epoch 128: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 25ms/step - loss: 0.7909 - accuracy: 0.7097 - val_loss: 0.9853 - val_accuracy: 0.6421 - lr: 1.0000e-07
# Epoch 129/150
# 897/897 [============================>.] - ETA: 0s - loss: 0.7922 - accuracy: 0.7048
# Epoch 129: val_loss did not improve from 0.98082
#
# Epoch 129: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 897/897 [==============================] - 24s 27ms/step - loss: 0.7920 - accuracy: 0.7048 - val_loss: 0.9861 - val_accuracy: 0.6428 - lr: 1.0000e-07
# Epoch 130/150
# 898/897 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.7057
# Epoch 130: val_loss did not improve from 0.98082
# 897/897 [==============================] - 23s 26ms/step - loss: 0.7937 - accuracy: 0.7057 - val_loss: 0.9858 - val_accuracy: 0.6431 - lr: 1.0000e-08
# Epoch 131/150
# 896/897 [============================>.] - ETA: 0s - loss: 0.7981 - accuracy: 0.7045
# Epoch 131: val_loss did not improve from 0.98082
# 897/897 [==============================] - 25s 27ms/step - loss: 0.7982 - accuracy: 0.7044 - val_loss: 0.9868 - val_accuracy: 0.6422 - lr: 1.0000e-08
